# %%
import nltk
import pandas as pd
from glob import glob
import os
import pandas as pd
from pprint import pprint

# %%
datadir = r"C:\Users\keatu\Regis_archive\practicum_data"
fbdf = pd.read_csv(os.path.join(datadir,"trimmed_fb_data.csv"))

# %%
search_terms = ["blood clot","heart","cardiovascular","stroke","deep vein thrombosis","embolism","out of breath","shortness of breath","heparin","warfarin","rapid heartbeat","lightheaded","sweat","fever","leg pain","leg swelling", "leg swollen","clammy skin","discolor skin","cyanosis"]

# %%
termdf = fbdf[fbdf["text"].apply(lambda x: x.lower()).str.contains("|".join(search_terms))]

# %%
# Out:
# "#IgE, #MastCells, #Basophils, and #Eosinophils\n\n#IgE, mast cells, basophils, and eosinophils are essential components of allergic inflammation. Antigen-specific IgE production, with subsequent fixation of IgE to FcRI receptors on mast cells and basophils, is central to the initiation and propagation of immediate hypersensitivity reactions.\n\nMast cells, basophils, and eosinophils are central effector cells in #allergic #inflammation, as well as in innate and adaptive immunity. This review highlights what is known about these components and their roles in disease pathogenesis.\n\nV. Conclusion\n\nMast cells, basophils and eosinophils express many of the same receptors and #cytokines, yet have different effector functions.\nMast cells are tissue resident cells and uniquely required for immediate hypersensitivity.\n\nBasophils are largely circulating cells, but home to areas of allergic inflammation during the late phase response.\n\nEosinophils are resident to the GI tract, but als
# ...
